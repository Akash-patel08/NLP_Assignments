# %% [markdown]
# # Lab Assignment 1: NLP Techniques
#
# This notebook demonstrates Tokenization, Stemming, and Lemmatization using NLTK.

# %% [markdown]
# ## Import Libraries in system

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')

from nltk.tokenize import WhitespaceTokenizer, wordpunct_tokenize, TreebankWordTokenizer, TweetTokenizer, MWETokenizer
from nltk.stem import PorterStemmer, SnowballStemmer, WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\akash\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\akash\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Input Text

# %%
text = "Don't worry! Loving #NLP @OpenAI 😊 natural language processing"
print(text)
# Out:
# Don't worry! Loving #NLP @OpenAI 😊 natural language processing

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### 1) Whitespace Tokenizer

# %%
wt = WhitespaceTokenizer()
print(wt.tokenize(text))
# Out:
# ["Don't", 'worry!', 'Loving', '#NLP', '@OpenAI', '😊', 'natural', 'language', 'processing']

# %% [markdown]
# ### 2) Punctuation Tokenizer

# %%
print(wordpunct_tokenize(text))
# Out:
# ['Don', "'", 't', 'worry', '!', 'Loving', '#', 'NLP', '@', 'OpenAI', '😊', 'natural', 'language', 'processing']

# %% [markdown]
# ### 3) Treebank Tokenizer

# %%
twt = TreebankWordTokenizer()
print(twt.tokenize(text))
# Out:
# ['Do', "n't", 'worry', '!', 'Loving', '#', 'NLP', '@', 'OpenAI', '😊', 'natural', 'language', 'processing']

# %% [markdown]
# ### 4) Tweet Tokenizer

# %%
tweet = TweetTokenizer()
print(tweet.tokenize(text))
# Out:
# ["Don't", 'worry', '!', 'Loving', '#NLP', '@OpenAI', '😊', 'natural', 'language', 'processing']

# %% [markdown]
# ### 5) MWE Tokenizer

# %%
mwe = MWETokenizer([('natural', 'language')], separator='_')
print(mwe.tokenize(text.split()))
# Out:
# ["Don't", 'worry!', 'Loving', '#NLP', '@OpenAI', '😊', 'natural_language', 'processing']

# %% [markdown]
# ## Stemming

# %%
words = ['running', 'studies', 'connection', 'better']
print(words)
# Out:
# ['running', 'studies', 'connection', 'better']

# %% [markdown]
# ### 1) Porter Stemmer

# %%
ps = PorterStemmer()
for w in words:
    print(w, "→", ps.stem(w))
# Out:
# running → run
# studies → studi
# connection → connect
# better → better

# %% [markdown]
# ### 2) Snowball Stemmer

# %%
ss = SnowballStemmer("english")
for w in words:
    print(w, "→", ss.stem(w))
# Out:
# running → run
# studies → studi
# connection → connect
# better → better

# %% [markdown]
# ## Lemmatization (WordNet)

# %%
lemmatizer = WordNetLemmatizer()
for w in words:
    print(w, "→", lemmatizer.lemmatize(w))
# Out:
# running → running
# studies → study
# connection → connection
# better → better

# %% [markdown]
# ## Conclusion
# Tokenization splits text, Stemming reduces words to roots, and Lemmatization provides meaningful base words.
